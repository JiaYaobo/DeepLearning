# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Model, Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, GlobalAveragePooling2D, Dense, Dropout, Lambda
from keras.layers import concatenate
from keras.layers import Resizing
from keras import datasets, losses

# %%
def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
  # Input: 
  # - f1: number of filters of the 1x1 convolutional layer in the first path
  # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
  # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
  # - f4: number of filters of the 1x1 convolutional layer in the fourth path

  # 1st path:
  path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

  # 2nd path
  path2 = Conv2D(filters = f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path2 = Conv2D(filters = f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # 3rd path
  path3 = Conv2D(filters = f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path3 = Conv2D(filters = f3_conv5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
  path4 = Conv2D(filters = f4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %%
def GoogLeNet():
  # input layer 
  input_layer = Input(shape = (224, 224, 3))
  # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
  X = Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

  # 2nd Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 3rd Inception block
  X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)

  # Extra network 1:
  X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = Flatten()(X1)
  X1 = Dense(1024, activation = 'relu')(X1)
  X1 = Dropout(0.7)(X1)
  X1 = Dense(5, activation = 'softmax')(X1)

  
  # 4th Inception block
  X = Inception_block(X, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 5th Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 6th Inception block
  X = Inception_block(X, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)

  # Extra network 2:
  X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = Flatten()(X2)
  X2 = Dense(1024, activation = 'relu')(X2)
  X2 = Dropout(0.7)(X2)
  X2 = Dense(1000, activation = 'softmax')(X2)
  
  
  # 7th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, 
                      f3_conv5 = 128, f4 = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # 8th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

  # 9th Inception block
  X = Inception_block(X, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

  # Global Average pooling layer 
  X = GlobalAveragePooling2D(name = 'GAPL')(X)

  # Dropoutlayer 
  X = Dropout(0.4)(X)

  # output layer 
  X = Dense(1000, activation = 'softmax')(X)
  
  # model
  model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet')

  return model

# %%
(x_train,y_train),(x_test,y_test) = datasets.mnist.load_data()
x_train = tf.pad(x_train, [[0, 0], [2,2], [2,2]])/255
x_test = tf.pad(x_test, [[0, 0], [2,2], [2,2]])/255
x_train = tf.expand_dims(x_train, axis=3, name=None)
x_test = tf.expand_dims(x_test, axis=3, name=None)
x_train = tf.repeat(x_train, 3, axis=3)
x_test = tf.repeat(x_test, 3, axis=3)
x_val = x_train[-2000:,:,:,:]
y_val = y_train[-2000:]
x_train = x_train[:-2000,:,:,:]
y_train = y_train[:-2000]

# %%
model = Sequential()
model.add(Resizing(224, 224, interpolation="bilinear", input_shape=(32, 32, 3)))
model.add(Lambda(GoogLeNet))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [30], line 3
#       1 model = Sequential()
#       2 model.add(Resizing(224, 224, interpolation="bilinear", input_shape=(32, 32, 3)))
# ----> 3 model.add(Lambda(GoogLeNet))
#
# File /opt/miniconda3/envs/tf/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py:587, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     585 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     586 try:
# --> 587   result = method(self, *args, **kwargs)
#     588 finally:
#     589   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File /opt/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File /opt/miniconda3/envs/tf/lib/python3.9/site-packages/keras/layers/core/lambda_layer.py:196, in Lambda.call(self, inputs, mask, training)
#     192   return var
#     194 with tf.GradientTape(watch_accessed_variables=True) as tape,\
#     195     tf.variable_creator_scope(_variable_creator):
# --> 196   result = self.function(inputs, **kwargs)
#     197 self._check_variables(created_variables, tape.watched_variables())
#     198 return result
#
# TypeError: Exception encountered when calling layer "lambda_1" (type Lambda).
#
# GoogLeNet() takes 0 positional arguments but 1 was given
#
# Call arguments received by layer "lambda_1" (type Lambda):
#   • inputs=tf.Tensor(shape=(None, 224, 224, 3), dtype=float32)
#   • mask=None
#   • training=False

# %%
model.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_61 (Conv2D)             (None, 109, 109, 64  9472        ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_13 (MaxPooling2D  (None, 54, 54, 64)  0           ['conv2d_61[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 54, 54, 64)   4160        ['max_pooling2d_13[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 54, 54, 192)  110784      ['conv2d_62[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 26, 26, 192)  0          ['conv2d_63[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 26, 26, 96)   18528       ['max_pooling2d_14[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 26, 26, 16)   3088        ['max_pooling2d_14[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 26, 26, 192)  0          ['max_pooling2d_14[0][0]']
#  )
#
#  conv2d_64 (Conv2D)             (None, 26, 26, 64)   12352       ['max_pooling2d_14[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 26, 26, 128)  110720      ['conv2d_65[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 26, 26, 32)   12832       ['conv2d_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 26, 26, 32)   6176        ['max_pooling2d_15[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 26, 26, 256)  0           ['conv2d_64[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 26, 26, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 26, 26, 32)   8224        ['concatenate_9[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 26, 26, 256)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_70 (Conv2D)             (None, 26, 26, 128)  32896       ['concatenate_9[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 26, 26, 192)  221376      ['conv2d_71[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 26, 26, 96)   76896       ['conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 26, 26, 64)   16448       ['max_pooling2d_16[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 26, 26, 480)  0           ['conv2d_70[0][0]',
#                                                                   'conv2d_72[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 12, 12, 480)  0          ['concatenate_10[0][0]']
#  )
#
#  conv2d_77 (Conv2D)             (None, 12, 12, 96)   46176       ['max_pooling2d_17[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 12, 12, 16)   7696        ['max_pooling2d_17[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 12, 12, 480)  0          ['max_pooling2d_17[0][0]']
#  )
#
#  conv2d_76 (Conv2D)             (None, 12, 12, 192)  92352       ['max_pooling2d_17[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 12, 12, 208)  179920      ['conv2d_77[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 12, 12, 48)   19248       ['conv2d_79[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 12, 12, 64)   30784       ['max_pooling2d_18[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 12, 12, 512)  0           ['conv2d_76[0][0]',
#                                                                   'conv2d_78[0][0]',
#                                                                   'conv2d_80[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 12, 12, 112)  57456       ['concatenate_11[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 12, 12, 24)   12312       ['concatenate_11[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 12, 12, 512)  0          ['concatenate_11[0][0]']
#  )
#
#  conv2d_83 (Conv2D)             (None, 12, 12, 160)  82080       ['concatenate_11[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 12, 12, 224)  226016      ['conv2d_84[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_19[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 12, 12, 512)  0           ['conv2d_83[0][0]',
#                                                                   'conv2d_85[0][0]',
#                                                                   'conv2d_87[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 12, 12, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 12, 12, 24)   12312       ['concatenate_12[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 12, 12, 512)  0          ['concatenate_12[0][0]']
#  )
#
#  conv2d_89 (Conv2D)             (None, 12, 12, 128)  65664       ['concatenate_12[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 12, 12, 256)  295168      ['conv2d_90[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_92[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_20[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 12, 12, 512)  0           ['conv2d_89[0][0]',
#                                                                   'conv2d_91[0][0]',
#                                                                   'conv2d_93[0][0]',
#                                                                   'conv2d_94[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 12, 12, 144)  73872       ['concatenate_13[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 12, 12, 32)   16416       ['concatenate_13[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 12, 12, 512)  0          ['concatenate_13[0][0]']
#  )
#
#  conv2d_95 (Conv2D)             (None, 12, 12, 112)  57456       ['concatenate_13[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 12, 12, 288)  373536      ['conv2d_96[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 12, 12, 64)   51264       ['conv2d_98[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 12, 12, 64)   32832       ['max_pooling2d_21[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 12, 12, 528)  0           ['conv2d_95[0][0]',
#                                                                   'conv2d_97[0][0]',
#                                                                   'conv2d_99[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 12, 12, 160)  84640       ['concatenate_14[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 12, 12, 32)   16928       ['concatenate_14[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 12, 12, 528)  0          ['concatenate_14[0][0]']
#  )
#
#  conv2d_102 (Conv2D)            (None, 12, 12, 256)  135424      ['concatenate_14[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 12, 12, 320)  461120      ['conv2d_103[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 12, 12, 128)  102528      ['conv2d_105[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 12, 12, 128)  67712       ['max_pooling2d_22[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 12, 12, 832)  0           ['conv2d_102[0][0]',
#                                                                   'conv2d_104[0][0]',
#                                                                   'conv2d_106[0][0]',
#                                                                   'conv2d_107[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 5, 5, 832)   0           ['concatenate_15[0][0]']
#  )
#
#  conv2d_109 (Conv2D)            (None, 5, 5, 160)    133280      ['max_pooling2d_23[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 5, 5, 32)     26656       ['max_pooling2d_23[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 5, 5, 832)   0           ['max_pooling2d_23[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 5, 5, 256)    213248      ['max_pooling2d_23[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 5, 5, 320)    461120      ['conv2d_109[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 5, 5, 128)    102528      ['conv2d_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 5, 5, 128)    106624      ['max_pooling2d_24[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 5, 5, 832)    0           ['conv2d_108[0][0]',
#                                                                   'conv2d_110[0][0]',
#                                                                   'conv2d_112[0][0]',
#                                                                   'conv2d_113[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 5, 5, 192)    159936      ['concatenate_16[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 5, 5, 48)     39984       ['concatenate_16[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 5, 5, 832)   0           ['concatenate_16[0][0]']
#  )
#
#  average_pooling2d_2 (AveragePo  (None, 3, 3, 512)   0           ['concatenate_11[0][0]']
#  oling2D)
#
#  average_pooling2d_3 (AveragePo  (None, 3, 3, 528)   0           ['concatenate_14[0][0]']
#  oling2D)
#
#  conv2d_114 (Conv2D)            (None, 5, 5, 384)    319872      ['concatenate_16[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 5, 5, 384)    663936      ['conv2d_115[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 5, 5, 128)    153728      ['conv2d_117[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 5, 5, 128)    106624      ['max_pooling2d_25[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 3, 3, 128)    65664       ['average_pooling2d_2[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 3, 3, 128)    67712       ['average_pooling2d_3[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 5, 5, 1024)   0           ['conv2d_114[0][0]',
#                                                                   'conv2d_116[0][0]',
#                                                                   'conv2d_118[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  flatten_2 (Flatten)            (None, 1152)         0           ['conv2d_82[0][0]']
#
#  flatten_3 (Flatten)            (None, 1152)         0           ['conv2d_101[0][0]']
#
#  GAPL (GlobalAveragePooling2D)  (None, 1024)         0           ['concatenate_17[0][0]']
#
#  dense_5 (Dense)                (None, 1024)         1180672     ['flatten_2[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         1180672     ['flatten_3[0][0]']
#
#  dropout_5 (Dropout)            (None, 1024)         0           ['GAPL[0][0]']
#
#  dropout_3 (Dropout)            (None, 1024)         0           ['dense_5[0][0]']
#
#  dropout_4 (Dropout)            (None, 1024)         0           ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 1000)         1025000     ['dropout_5[0][0]']
#
#  dense_6 (Dense)                (None, 5)            5125        ['dropout_3[0][0]']
#
#  dense_8 (Dense)                (None, 1000)         1025000     ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 10,523,397
# Trainable params: 10,523,397
# Non-trainable params: 0
# __________________________________________________________________________________________________
